# %% [markdown]
# ## Train a semantic segmentation unet using Pytorch

# %% [markdown]
# ## Pytorch setup
#
# setting up environment (Windows 10 with Cuda 11.8)
#
# ```
# conda create --name pytorch_tests python=3.10
# conda activate pytorch_tests
# conda install pip
# pip install pykernel
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# pip install pytorch-lightning
# pip install monai
# pip install scipy
# pip install tifffile
# pip install matplotlib
# ```

# %% [markdown]
# ## Imports

# %%
from skimage.io import imread
from tqdm import tqdm
from data import quantile_normalization
import matplotlib.pyplot as plt
import numpy as np
import torch

from torchvision import transforms
from torchvision.transforms import v2
import torchvision.transforms.functional as TF

# %% [markdown]
# ## Set up image and label directories

# %%
from pathlib import Path
import json

parent_path=Path(r'../../data/roots')
train_path= parent_path / 'patches' 

with open(train_path / 'info.json', 'r') as json_file:
    data = json.load(json_file)
    # Access the sub_sample parameter
    sub_sample = data['sub_sample']
    print('sub_sample',sub_sample)
    axes = data['axes']
    print('axes',axes)

image_patch_path = train_path / 'ground truth0'
label_patch_path = train_path / 'input0'
# Out:
# sub_sample 1
# axes YX

# %% [markdown]
# ## Create a Dataset for the plant root data
#
# Dataset is simply used to retrieve the training patches.  In this case we just set it up to read in image files, then convert the numpy arrays to tensors and a torch stack.
#
# In this example augmentation was done in a previous notebook, and the augmented images explicitly saved.  It is also possible to do augmentation as the data is retrieved.  So in the future the ```PlantRootData``` could be extended to apply augmentation as data is retrieved.

# %%
class PlantRootData():

    def __init__(self, image_files, label_files, target_shape=(256, 256)):
            """
            Parameters
            ----------
            image_files: list of pathlib.Path objects pointing to the *.tif images
            label_files: list of pathlib.Path objects pointing to the *.tif segmentation masks
            target_shape: tuple of length 2 specifying the sample resolutions of files that
                        will be kept. All other files will NOT be used.
            """
            assert len(image_files) == len(label_files)
            assert all(x.name==y.name for x,y in zip(image_files, label_files))

            self.images = []
            self.labels = []

            tensor_transform = transforms.Compose([
                v2.ToTensor(),
            ])

            # use tqdm to have eye pleasing error bars
            for idx in tqdm(range(len(image_files))):
                # we use the same data reading approach as in the previous notebook
                image = imread(image_files[idx])
                label = imread(label_files[idx])

                if image.shape != target_shape:
                    continue
                
                # do the normalizations
                #image = quantile_normalization(
                #    image,
                #    quantile_low=0.01,
                #    quantile_high=0.998,
                #    clip=True)[0].astype(np.float32)

                # NOTE: we convert the label to dtype float32 and not uint8 because
                # the tensor transformation does a normalization if the input is of
                # dtype uint8, destroying the 0/1 labelling which we want to avoid.
                #label = fill_label_holes(label)
                label_binary = np.zeros_like(label).astype(np.float32)
                label_binary[label != 0] = 1.
                

                # convert to torch tensor: adds an artificial color channel in the front
                # and scales inputs to have same size as samples tend to differ in image
                # resolutions
                image = tensor_transform(image)
                label = tensor_transform(label_binary)

                self.images.append(image)
                self.labels.append(label)

            self.images = torch.stack(self.images)
            self.labels = torch.stack(self.labels)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    def __len__(self):
        return len(self.images)

# %% [markdown]
# ## Initialize the PlantRootData
#
# Initialize the DataSet with the pre-generated patch names

# %%
src_dir = train_path

assert src_dir.exists(), f"root directory with images and masks {src_dir} does not exist"

X = sorted(src_dir.rglob('**/input0/*.tif'))
Y = sorted(src_dir.rglob('**/ground truth0/*.tif'))

train_data = PlantRootData(
    image_files=X,
    label_files=Y,
    target_shape=(448, 448)
)

# NOTE: the length of the dataset might not be the same as n_samples
#       because files not having the target shape will be discarded
print(len(train_data))
# Out:
# c:\Users\bnort\miniconda3\envs\pytorch_tests2\lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(
# 100%|██████████| 450/450 [00:01<00:00, 350.04it/s]
# 450

# %% [markdown]
# ## Create a DataLoader
#
# This is done so we can load batches of images.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %% [markdown]
# ## Check if GPU is present

# %%
cuda_present = torch.cuda.is_available()
ndevices = torch.cuda.device_count()
use_cuda = cuda_present and ndevices > 0
device = torch.device("cuda" if use_cuda else "cpu")  # "cuda:0" ... default device, "cuda:1" would be GPU index 1, "cuda:2" etc
print("number of devices:", ndevices, "\tchosen device:", device, "\tuse_cuda=", use_cuda)
# Out:
# number of devices: 1 	chosen device: cuda 	use_cuda= True

# %% [markdown]
# ## Create a UNET

# %%
from monai.networks.nets import BasicUNet

model = BasicUNet(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    #features=[16, 16, 32, 64, 128, 16],
    act="relu",
    norm="batch",
    dropout=0.25,
)

# Important: transfer the model to the chosen device
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1.e-3)
init_params = list(model.parameters())[0].clone().detach()
# Out:
# BasicUNet features: (32, 32, 64, 128, 256, 32).

# %% [markdown]
# ## Train the UNET

# %%
max_nepochs = 400 
log_interval = 1
model.train(True)

# BCEWithLogitsLoss combines sigmoid + BCELoss for better
# numerical stability. It expects raw unnormalized scores as input which are shaped like 
# B x C x W x D
loss_function = torch.nn.BCEWithLogitsLoss(reduction="mean")

for epoch in range(1, max_nepochs + 1):
    for batch_idx, (X, y) in enumerate(train_loader):
        # the inputs and labels have to be on the same device as the model
        print(X.shape, y.shape)
        # print data tyhpe of the tensor
        print(X.dtype, y.dtype)
        
        
        X, y = X.to(device), y.to(device)

        
        
        optimizer.zero_grad()

        prediction_logits = model(X)
        
        batch_loss = loss_function(prediction_logits, y)

        batch_loss.backward()

        optimizer.step()

        if batch_idx % log_interval == 0:
            print(
                "Train Epoch:",
                epoch,
                "Batch:",
                batch_idx,
                "Total samples processed:",
                (batch_idx + 1) * train_loader.batch_size,
                "Loss:",
                batch_loss.item(),
            )
# Out:
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 0 Total samples processed: 32 Loss: 0.6706418395042419
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 1 Total samples processed: 64 Loss: 0.6537203788757324
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 2 Total samples processed: 96 Loss: 0.6390042901039124
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 3 Total samples processed: 128 Loss: 0.6254482269287109
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 4 Total samples processed: 160 Loss: 0.6118168830871582
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 5 Total samples processed: 192 Loss: 0.5975738167762756
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 6 Total samples processed: 224 Loss: 0.5860639810562134
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 7 Total samples processed: 256 Loss: 0.5680401921272278
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 8 Total samples processed: 288 Loss: 0.5530428886413574
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 9 Total samples processed: 320 Loss: 0.541088342666626
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 10 Total samples processed: 352 Loss: 0.5290845632553101
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 11 Total samples processed: 384 Loss: 0.5153185129165649
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 12 Total samples processed: 416 Loss: 0.5029488801956177
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 13 Total samples processed: 448 Loss: 0.4912642240524292
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 1 Batch: 14 Total samples processed: 480 Loss: 0.4811134934425354
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 0 Total samples processed: 32 Loss: 0.48047173023223877
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 1 Total samples processed: 64 Loss: 0.45355865359306335
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 2 Total samples processed: 96 Loss: 0.45017439126968384
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 3 Total samples processed: 128 Loss: 0.4474126100540161
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 4 Total samples processed: 160 Loss: 0.4445512890815735
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 5 Total samples processed: 192 Loss: 0.4359946548938751
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 6 Total samples processed: 224 Loss: 0.42865005135536194
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 7 Total samples processed: 256 Loss: 0.42106616497039795
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 8 Total samples processed: 288 Loss: 0.4156874418258667
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 9 Total samples processed: 320 Loss: 0.4056451916694641
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 10 Total samples processed: 352 Loss: 0.4021182060241699
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 11 Total samples processed: 384 Loss: 0.39525213837623596
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 12 Total samples processed: 416 Loss: 0.39083725214004517
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 13 Total samples processed: 448 Loss: 0.38380181789398193
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 2 Batch: 14 Total samples processed: 480 Loss: 0.3675619661808014
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 0 Total samples processed: 32 Loss: 0.37345388531684875
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 1 Total samples processed: 64 Loss: 0.36978572607040405
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 2 Total samples processed: 96 Loss: 0.3729420006275177
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 3 Total samples processed: 128 Loss: 0.3597875237464905
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 4 Total samples processed: 160 Loss: 0.35523292422294617
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 5 Total samples processed: 192 Loss: 0.3518351912498474
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 6 Total samples processed: 224 Loss: 0.3477083146572113
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 7 Total samples processed: 256 Loss: 0.3445942997932434
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 8 Total samples processed: 288 Loss: 0.34014588594436646
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 9 Total samples processed: 320 Loss: 0.34016838669776917
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 10 Total samples processed: 352 Loss: 0.33166468143463135
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 11 Total samples processed: 384 Loss: 0.33108481764793396
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 12 Total samples processed: 416 Loss: 0.36064693331718445
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 13 Total samples processed: 448 Loss: 0.3208249807357788
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 3 Batch: 14 Total samples processed: 480 Loss: 0.3488566279411316
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 0 Total samples processed: 32 Loss: 0.3218136429786682
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 1 Total samples processed: 64 Loss: 0.3206864893436432
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 2 Total samples processed: 96 Loss: 0.31841087341308594
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 3 Total samples processed: 128 Loss: 0.30716800689697266
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 4 Total samples processed: 160 Loss: 0.3127756714820862
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 5 Total samples processed: 192 Loss: 0.30720895528793335
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 6 Total samples processed: 224 Loss: 0.30342522263526917
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 7 Total samples processed: 256 Loss: 0.29784804582595825
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 8 Total samples processed: 288 Loss: 0.3014817237854004
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 9 Total samples processed: 320 Loss: 0.299596905708313
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 10 Total samples processed: 352 Loss: 0.2884882390499115
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 11 Total samples processed: 384 Loss: 0.29163116216659546
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 12 Total samples processed: 416 Loss: 0.29124540090560913
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 13 Total samples processed: 448 Loss: 0.2847976088523865
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 4 Batch: 14 Total samples processed: 480 Loss: 0.288968563079834
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 0 Total samples processed: 32 Loss: 0.28198468685150146
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 1 Total samples processed: 64 Loss: 0.2737084627151489
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 2 Total samples processed: 96 Loss: 0.27161329984664917
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 3 Total samples processed: 128 Loss: 0.2701047360897064
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 4 Total samples processed: 160 Loss: 0.26722803711891174
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 5 Total samples processed: 192 Loss: 0.26777270436286926
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 6 Total samples processed: 224 Loss: 0.26650798320770264
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 7 Total samples processed: 256 Loss: 0.26494818925857544
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 8 Total samples processed: 288 Loss: 0.26694637537002563
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 9 Total samples processed: 320 Loss: 0.25165659189224243
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 10 Total samples processed: 352 Loss: 0.2586815357208252
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 11 Total samples processed: 384 Loss: 0.2553311586380005
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 12 Total samples processed: 416 Loss: 0.24819575250148773
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 13 Total samples processed: 448 Loss: 0.2517260015010834
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 5 Batch: 14 Total samples processed: 480 Loss: 0.2789223790168762
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 0 Total samples processed: 32 Loss: 0.24279123544692993
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 1 Total samples processed: 64 Loss: 0.2416914701461792
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 2 Total samples processed: 96 Loss: 0.24946746230125427
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 3 Total samples processed: 128 Loss: 0.24846994876861572
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 4 Total samples processed: 160 Loss: 0.23834413290023804
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 5 Total samples processed: 192 Loss: 0.23870770633220673
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 6 Total samples processed: 224 Loss: 0.2325441688299179
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 7 Total samples processed: 256 Loss: 0.24085359275341034
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 8 Total samples processed: 288 Loss: 0.23430052399635315
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 9 Total samples processed: 320 Loss: 0.23009160161018372
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 10 Total samples processed: 352 Loss: 0.2364148050546646
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 11 Total samples processed: 384 Loss: 0.22557534277439117
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 12 Total samples processed: 416 Loss: 0.21994833648204803
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 13 Total samples processed: 448 Loss: 0.22654668986797333
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 6 Batch: 14 Total samples processed: 480 Loss: 0.2125658392906189
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 0 Total samples processed: 32 Loss: 0.21981433033943176
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 1 Total samples processed: 64 Loss: 0.21729713678359985
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 2 Total samples processed: 96 Loss: 0.21905343234539032
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 3 Total samples processed: 128 Loss: 0.21742644906044006
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 4 Total samples processed: 160 Loss: 0.20554105937480927
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 5 Total samples processed: 192 Loss: 0.20759780704975128
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 6 Total samples processed: 224 Loss: 0.21131198108196259
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 7 Total samples processed: 256 Loss: 0.21886079013347626
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 8 Total samples processed: 288 Loss: 0.2032836526632309
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 9 Total samples processed: 320 Loss: 0.21253308653831482
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 10 Total samples processed: 352 Loss: 0.2073204666376114
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 11 Total samples processed: 384 Loss: 0.20371751487255096
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 12 Total samples processed: 416 Loss: 0.20283165574073792
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 13 Total samples processed: 448 Loss: 0.20059294998645782
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 7 Batch: 14 Total samples processed: 480 Loss: 0.18095895648002625
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 0 Total samples processed: 32 Loss: 0.1968609094619751
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 1 Total samples processed: 64 Loss: 0.19302746653556824
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 2 Total samples processed: 96 Loss: 0.20002537965774536
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 3 Total samples processed: 128 Loss: 0.19737790524959564
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 4 Total samples processed: 160 Loss: 0.19310706853866577
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 5 Total samples processed: 192 Loss: 0.19478417932987213
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 6 Total samples processed: 224 Loss: 0.1883833259344101
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 7 Total samples processed: 256 Loss: 0.1867222636938095
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 8 Total samples processed: 288 Loss: 0.18413931131362915
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 9 Total samples processed: 320 Loss: 0.1885998398065567
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 10 Total samples processed: 352 Loss: 0.18166594207286835
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 11 Total samples processed: 384 Loss: 0.19558267295360565
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 12 Total samples processed: 416 Loss: 0.18418288230895996
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 13 Total samples processed: 448 Loss: 0.18004260957241058
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 8 Batch: 14 Total samples processed: 480 Loss: 0.17099829018115997
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 0 Total samples processed: 32 Loss: 0.18754896521568298
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 1 Total samples processed: 64 Loss: 0.17887656390666962
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 2 Total samples processed: 96 Loss: 0.1752510964870453
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 3 Total samples processed: 128 Loss: 0.1796114146709442
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 4 Total samples processed: 160 Loss: 0.17327511310577393
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 5 Total samples processed: 192 Loss: 0.1729821115732193
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 6 Total samples processed: 224 Loss: 0.17924514412879944
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 7 Total samples processed: 256 Loss: 0.17244334518909454
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 8 Total samples processed: 288 Loss: 0.17596688866615295
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 9 Total samples processed: 320 Loss: 0.1816534399986267
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 10 Total samples processed: 352 Loss: 0.16855667531490326
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 11 Total samples processed: 384 Loss: 0.166901096701622
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 12 Total samples processed: 416 Loss: 0.1669422686100006
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 13 Total samples processed: 448 Loss: 0.16741125285625458
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 9 Batch: 14 Total samples processed: 480 Loss: 0.2048216015100479
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 0 Total samples processed: 32 Loss: 0.1662624329328537
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 1 Total samples processed: 64 Loss: 0.16474412381649017
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 2 Total samples processed: 96 Loss: 0.17680004239082336
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 3 Total samples processed: 128 Loss: 0.16112667322158813
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 4 Total samples processed: 160 Loss: 0.1615791767835617
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 5 Total samples processed: 192 Loss: 0.17210480570793152
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 6 Total samples processed: 224 Loss: 0.1610780656337738
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 7 Total samples processed: 256 Loss: 0.15979410707950592
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 8 Total samples processed: 288 Loss: 0.15401200950145721
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 9 Total samples processed: 320 Loss: 0.15937693417072296
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 10 Total samples processed: 352 Loss: 0.15916374325752258
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 11 Total samples processed: 384 Loss: 0.15234214067459106
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 12 Total samples processed: 416 Loss: 0.1553715318441391
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 13 Total samples processed: 448 Loss: 0.14809833467006683
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 10 Batch: 14 Total samples processed: 480 Loss: 0.16577377915382385
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 0 Total samples processed: 32 Loss: 0.1489795595407486
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 1 Total samples processed: 64 Loss: 0.15470413863658905
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 2 Total samples processed: 96 Loss: 0.15621483325958252
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 3 Total samples processed: 128 Loss: 0.14930178225040436
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 4 Total samples processed: 160 Loss: 0.14287148416042328
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 5 Total samples processed: 192 Loss: 0.1465219408273697
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 6 Total samples processed: 224 Loss: 0.16175130009651184
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 7 Total samples processed: 256 Loss: 0.15354743599891663
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 8 Total samples processed: 288 Loss: 0.1458895355463028
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 9 Total samples processed: 320 Loss: 0.14241530001163483
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 10 Total samples processed: 352 Loss: 0.1518854945898056
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 11 Total samples processed: 384 Loss: 0.14235779643058777
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 12 Total samples processed: 416 Loss: 0.14052265882492065
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 13 Total samples processed: 448 Loss: 0.1477399319410324
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 11 Batch: 14 Total samples processed: 480 Loss: 0.16625693440437317
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 0 Total samples processed: 32 Loss: 0.1427707076072693
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 1 Total samples processed: 64 Loss: 0.14751243591308594
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 2 Total samples processed: 96 Loss: 0.13813938200473785
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 3 Total samples processed: 128 Loss: 0.14304108917713165
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 4 Total samples processed: 160 Loss: 0.1439245492219925
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 5 Total samples processed: 192 Loss: 0.13450735807418823
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 6 Total samples processed: 224 Loss: 0.14702236652374268
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 7 Total samples processed: 256 Loss: 0.1374320238828659
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 8 Total samples processed: 288 Loss: 0.13714779913425446
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 9 Total samples processed: 320 Loss: 0.13359056413173676
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 10 Total samples processed: 352 Loss: 0.1313808709383011
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 11 Total samples processed: 384 Loss: 0.12873072922229767
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 12 Total samples processed: 416 Loss: 0.1320047378540039
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 13 Total samples processed: 448 Loss: 0.13814321160316467
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 12 Batch: 14 Total samples processed: 480 Loss: 0.11344964057207108
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 0 Total samples processed: 32 Loss: 0.13158640265464783
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 1 Total samples processed: 64 Loss: 0.139646515250206
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 2 Total samples processed: 96 Loss: 0.12650923430919647
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 3 Total samples processed: 128 Loss: 0.12992607057094574
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 4 Total samples processed: 160 Loss: 0.13219474256038666
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 5 Total samples processed: 192 Loss: 0.13326039910316467
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 6 Total samples processed: 224 Loss: 0.14258112013339996
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 7 Total samples processed: 256 Loss: 0.1284594088792801
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 8 Total samples processed: 288 Loss: 0.11319899559020996
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 9 Total samples processed: 320 Loss: 0.12186945229768753
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 10 Total samples processed: 352 Loss: 0.12838415801525116
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 11 Total samples processed: 384 Loss: 0.12705650925636292
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 12 Total samples processed: 416 Loss: 0.13346178829669952
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 13 Total samples processed: 448 Loss: 0.13364747166633606
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 13 Batch: 14 Total samples processed: 480 Loss: 0.12128611654043198
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 0 Total samples processed: 32 Loss: 0.11935260146856308
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 1 Total samples processed: 64 Loss: 0.10963746160268784
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 2 Total samples processed: 96 Loss: 0.122721828520298
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 3 Total samples processed: 128 Loss: 0.13386096060276031
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 4 Total samples processed: 160 Loss: 0.11930854618549347
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 5 Total samples processed: 192 Loss: 0.1267937421798706
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 6 Total samples processed: 224 Loss: 0.11966532468795776
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 7 Total samples processed: 256 Loss: 0.119502492249012
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 8 Total samples processed: 288 Loss: 0.1312730461359024
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 9 Total samples processed: 320 Loss: 0.12823256850242615
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 10 Total samples processed: 352 Loss: 0.12634028494358063
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 11 Total samples processed: 384 Loss: 0.1152019053697586
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 12 Total samples processed: 416 Loss: 0.12469826638698578
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 13 Total samples processed: 448 Loss: 0.12503714859485626
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 14 Batch: 14 Total samples processed: 480 Loss: 0.11398345232009888
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 0 Total samples processed: 32 Loss: 0.11513800919055939
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 1 Total samples processed: 64 Loss: 0.12424098700284958
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 2 Total samples processed: 96 Loss: 0.11571052670478821
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 3 Total samples processed: 128 Loss: 0.1204695776104927
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 4 Total samples processed: 160 Loss: 0.12637858092784882
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 5 Total samples processed: 192 Loss: 0.12096971273422241
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 6 Total samples processed: 224 Loss: 0.11279796808958054
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 7 Total samples processed: 256 Loss: 0.12258776277303696
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 8 Total samples processed: 288 Loss: 0.11828833073377609
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 9 Total samples processed: 320 Loss: 0.11590015143156052
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 10 Total samples processed: 352 Loss: 0.11276809126138687
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 11 Total samples processed: 384 Loss: 0.11433225870132446
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 12 Total samples processed: 416 Loss: 0.11432099342346191
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 13 Total samples processed: 448 Loss: 0.1177961453795433
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 15 Batch: 14 Total samples processed: 480 Loss: 0.09925045818090439
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 0 Total samples processed: 32 Loss: 0.11860539764165878
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 1 Total samples processed: 64 Loss: 0.10965185612440109
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 2 Total samples processed: 96 Loss: 0.12539608776569366
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 3 Total samples processed: 128 Loss: 0.10157440602779388
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 4 Total samples processed: 160 Loss: 0.10604500770568848
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 5 Total samples processed: 192 Loss: 0.10219745337963104
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 6 Total samples processed: 224 Loss: 0.11698514223098755
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 7 Total samples processed: 256 Loss: 0.11223718523979187
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 8 Total samples processed: 288 Loss: 0.11610311269760132
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 9 Total samples processed: 320 Loss: 0.10604055225849152
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 10 Total samples processed: 352 Loss: 0.11214190721511841
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 11 Total samples processed: 384 Loss: 0.11051808297634125
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 12 Total samples processed: 416 Loss: 0.11294663697481155
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 13 Total samples processed: 448 Loss: 0.12326416373252869
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 16 Batch: 14 Total samples processed: 480 Loss: 0.0834982693195343
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 0 Total samples processed: 32 Loss: 0.10831311345100403
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 1 Total samples processed: 64 Loss: 0.11714670062065125
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 2 Total samples processed: 96 Loss: 0.1109498143196106
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 3 Total samples processed: 128 Loss: 0.1187419667840004
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 4 Total samples processed: 160 Loss: 0.10721702128648758
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 5 Total samples processed: 192 Loss: 0.11242727190256119
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 6 Total samples processed: 224 Loss: 0.0962553396821022
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 7 Total samples processed: 256 Loss: 0.1071707233786583
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 8 Total samples processed: 288 Loss: 0.10809148848056793
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 9 Total samples processed: 320 Loss: 0.1049279049038887
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 10 Total samples processed: 352 Loss: 0.10281248390674591
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 11 Total samples processed: 384 Loss: 0.098895363509655
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 12 Total samples processed: 416 Loss: 0.11213154345750809
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 13 Total samples processed: 448 Loss: 0.10659610480070114
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 17 Batch: 14 Total samples processed: 480 Loss: 0.07282356172800064
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 0 Total samples processed: 32 Loss: 0.10291354358196259
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 1 Total samples processed: 64 Loss: 0.10407686978578568
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 2 Total samples processed: 96 Loss: 0.09884440898895264
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 3 Total samples processed: 128 Loss: 0.10569723695516586
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 4 Total samples processed: 160 Loss: 0.10713502019643784
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 5 Total samples processed: 192 Loss: 0.10227266699075699
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 6 Total samples processed: 224 Loss: 0.10965628921985626
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 7 Total samples processed: 256 Loss: 0.1078227236866951
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 8 Total samples processed: 288 Loss: 0.09936803579330444
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 9 Total samples processed: 320 Loss: 0.1056780144572258
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 10 Total samples processed: 352 Loss: 0.10838058590888977
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 11 Total samples processed: 384 Loss: 0.09749679267406464
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 12 Total samples processed: 416 Loss: 0.09836023300886154
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 13 Total samples processed: 448 Loss: 0.10461696982383728
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 18 Batch: 14 Total samples processed: 480 Loss: 0.07573017477989197
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 0 Total samples processed: 32 Loss: 0.08978557586669922
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 1 Total samples processed: 64 Loss: 0.11148810386657715
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 2 Total samples processed: 96 Loss: 0.10280930995941162
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 3 Total samples processed: 128 Loss: 0.10410132259130478
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 4 Total samples processed: 160 Loss: 0.11639955639839172
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 5 Total samples processed: 192 Loss: 0.10817179083824158
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 6 Total samples processed: 224 Loss: 0.09210808575153351
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 7 Total samples processed: 256 Loss: 0.10624117404222488
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 8 Total samples processed: 288 Loss: 0.10062657296657562
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 9 Total samples processed: 320 Loss: 0.10252444446086884
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 10 Total samples processed: 352 Loss: 0.09488487243652344
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 11 Total samples processed: 384 Loss: 0.10466288030147552
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 12 Total samples processed: 416 Loss: 0.08816434442996979
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 13 Total samples processed: 448 Loss: 0.09043058753013611
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 19 Batch: 14 Total samples processed: 480 Loss: 0.08104801177978516
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 20 Batch: 0 Total samples processed: 32 Loss: 0.10023616254329681
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 20 Batch: 1 Total samples processed: 64 Loss: 0.0988440215587616
# ...
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 394 Batch: 11 Total samples processed: 384 Loss: 0.012023154646158218
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 394 Batch: 12 Total samples processed: 416 Loss: 0.01120197307318449
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 394 Batch: 13 Total samples processed: 448 Loss: 0.013380942866206169
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 394 Batch: 14 Total samples processed: 480 Loss: 0.012974097393453121
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 0 Total samples processed: 32 Loss: 0.014360089786350727
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 1 Total samples processed: 64 Loss: 0.01572832465171814
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 2 Total samples processed: 96 Loss: 0.010908428579568863
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 3 Total samples processed: 128 Loss: 0.01286170445382595
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 4 Total samples processed: 160 Loss: 0.011373715475201607
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 5 Total samples processed: 192 Loss: 0.01277942769229412
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 6 Total samples processed: 224 Loss: 0.011916124261915684
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 7 Total samples processed: 256 Loss: 0.01598219759762287
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 8 Total samples processed: 288 Loss: 0.017524443566799164
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 9 Total samples processed: 320 Loss: 0.012079328298568726
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 10 Total samples processed: 352 Loss: 0.012036903761327267
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 11 Total samples processed: 384 Loss: 0.011063561774790287
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 12 Total samples processed: 416 Loss: 0.014761148020625114
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 13 Total samples processed: 448 Loss: 0.0144810751080513
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 395 Batch: 14 Total samples processed: 480 Loss: 0.013222350738942623
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 0 Total samples processed: 32 Loss: 0.012242543511092663
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 1 Total samples processed: 64 Loss: 0.013214604929089546
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 2 Total samples processed: 96 Loss: 0.014355426654219627
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 3 Total samples processed: 128 Loss: 0.014310285449028015
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 4 Total samples processed: 160 Loss: 0.012129495851695538
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 5 Total samples processed: 192 Loss: 0.012855586595833302
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 6 Total samples processed: 224 Loss: 0.013960529118776321
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 7 Total samples processed: 256 Loss: 0.014825452119112015
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 8 Total samples processed: 288 Loss: 0.01244876068085432
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 9 Total samples processed: 320 Loss: 0.013110669329762459
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 10 Total samples processed: 352 Loss: 0.012945943512022495
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 11 Total samples processed: 384 Loss: 0.012915301136672497
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 12 Total samples processed: 416 Loss: 0.012921668589115143
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 13 Total samples processed: 448 Loss: 0.011180441826581955
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 396 Batch: 14 Total samples processed: 480 Loss: 0.027477456256747246
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 0 Total samples processed: 32 Loss: 0.012685495428740978
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 1 Total samples processed: 64 Loss: 0.012380927801132202
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 2 Total samples processed: 96 Loss: 0.01448814943432808
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 3 Total samples processed: 128 Loss: 0.012171288952231407
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 4 Total samples processed: 160 Loss: 0.015026588924229145
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 5 Total samples processed: 192 Loss: 0.01362323947250843
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 6 Total samples processed: 224 Loss: 0.01574026234447956
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 7 Total samples processed: 256 Loss: 0.013871125876903534
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 8 Total samples processed: 288 Loss: 0.01184452511370182
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 9 Total samples processed: 320 Loss: 0.013635704293847084
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 10 Total samples processed: 352 Loss: 0.014487971551716328
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 11 Total samples processed: 384 Loss: 0.01269079651683569
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 12 Total samples processed: 416 Loss: 0.014502959325909615
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 13 Total samples processed: 448 Loss: 0.013884641230106354
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 397 Batch: 14 Total samples processed: 480 Loss: 0.023913567885756493
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 0 Total samples processed: 32 Loss: 0.014558166265487671
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 1 Total samples processed: 64 Loss: 0.012228532694280148
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 2 Total samples processed: 96 Loss: 0.014181443490087986
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 3 Total samples processed: 128 Loss: 0.014497685246169567
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 4 Total samples processed: 160 Loss: 0.011865025386214256
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 5 Total samples processed: 192 Loss: 0.01290066633373499
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 6 Total samples processed: 224 Loss: 0.01154024712741375
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 7 Total samples processed: 256 Loss: 0.01394957397133112
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 8 Total samples processed: 288 Loss: 0.015718236565589905
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 9 Total samples processed: 320 Loss: 0.016316620633006096
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 10 Total samples processed: 352 Loss: 0.011547479778528214
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 11 Total samples processed: 384 Loss: 0.013674458488821983
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 12 Total samples processed: 416 Loss: 0.011585092172026634
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 13 Total samples processed: 448 Loss: 0.015412203036248684
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 398 Batch: 14 Total samples processed: 480 Loss: 0.026527009904384613
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 0 Total samples processed: 32 Loss: 0.014605101197957993
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 1 Total samples processed: 64 Loss: 0.013080443255603313
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 2 Total samples processed: 96 Loss: 0.01734369806945324
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 3 Total samples processed: 128 Loss: 0.013760758563876152
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 4 Total samples processed: 160 Loss: 0.015639424324035645
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 5 Total samples processed: 192 Loss: 0.014682990498840809
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 6 Total samples processed: 224 Loss: 0.013755359686911106
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 7 Total samples processed: 256 Loss: 0.012327088043093681
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 8 Total samples processed: 288 Loss: 0.013784983195364475
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 9 Total samples processed: 320 Loss: 0.010651282966136932
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 10 Total samples processed: 352 Loss: 0.013286301866173744
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 11 Total samples processed: 384 Loss: 0.013770703226327896
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 12 Total samples processed: 416 Loss: 0.016473280265927315
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 13 Total samples processed: 448 Loss: 0.014329827390611172
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 399 Batch: 14 Total samples processed: 480 Loss: 0.012324845418334007
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 0 Total samples processed: 32 Loss: 0.013548935763537884
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 1 Total samples processed: 64 Loss: 0.013708987273275852
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 2 Total samples processed: 96 Loss: 0.013851536437869072
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 3 Total samples processed: 128 Loss: 0.013886531814932823
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 4 Total samples processed: 160 Loss: 0.013361752964556217
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 5 Total samples processed: 192 Loss: 0.012854921631515026
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 6 Total samples processed: 224 Loss: 0.01487022265791893
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 7 Total samples processed: 256 Loss: 0.013683725148439407
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 8 Total samples processed: 288 Loss: 0.0130030931904912
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 9 Total samples processed: 320 Loss: 0.014384549111127853
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 10 Total samples processed: 352 Loss: 0.01194100920110941
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 11 Total samples processed: 384 Loss: 0.012461182661354542
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 12 Total samples processed: 416 Loss: 0.014542997814714909
# torch.Size([32, 1, 448, 448]) torch.Size([32, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 13 Total samples processed: 448 Loss: 0.014357841573655605
# torch.Size([2, 1, 448, 448]) torch.Size([2, 1, 448, 448])
# torch.float32 torch.float32
# Train Epoch: 400 Batch: 14 Total samples processed: 480 Loss: 0.01469887513667345

# %% [markdown]
# ## Look at self-prediction
#
# Self-prediction does not tell us how the UNET will perform on new data, but it is a useful check to make sure the UNET is learning the training data.

# %%
len(X)
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# convert to 0/1 range on each pixel
prediction = torch.nn.functional.sigmoid(prediction_logits)
prediction_binary = prediction #(prediction > 0.5).to(torch.uint8)

sidx = 1
plt.subplot(131)
plt.imshow(X[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Input")

plt.subplot(132)
plt.imshow(y[sidx, 0].cpu().numpy(), cmap="gray")
plt.title("Ground truth")

plt.subplot(133)
plt.imshow(prediction_binary.cpu().detach()[sidx, 0].numpy(), cmap="gray")
plt.title("Predictions")
# Out:
# Text(0.5, 1.0, 'Predictions')

# %% [markdown]
# ## Save the UNET

# %%
torch.save(model.state_dict(), train_path / 'model1')

# %% [markdown]
# ## Test on unseen data

# %%
parent_path=Path(r'../../data/roots')
test_image_path = Path(parent_path / r'images test')

files = list(test_image_path.glob('*.jpg'))

index = 1
testim = imread(files[index]) 
testim.shape
plt.imshow(testim, cmap="gray")
print('original min max', testim.min(), testim.max())
# Out:
# original min max 32 255

# %%
testim_ = testim.mean(axis=2).astype(np.float32)
testim_, _, _ = quantile_normalization(testim_)

x = torch.from_numpy(testim_).unsqueeze(0).unsqueeze(0).to(device)
y = model(x)

plt.imshow(y.cpu().detach()[0, 0].numpy(), cmap="gray")

# %% [markdown]
# ## Look at results in Napari

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(testim, name='testim')
viewer.add_image(y.cpu().detach()[0, 0].numpy(), name='prediction')
binary = y.cpu().detach()[0, 0].numpy() > 0.5
viewer.add_labels(binary, name='prediction binary')
# Out:
# <Labels layer 'prediction binary' at 0x22e7ee038b0>
